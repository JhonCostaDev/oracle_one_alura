# %% [markdown]
# Chegou a hora de você testar os conhecimentos desenvolvidos durante a aula. Nós temos um link do [Google Planilhas](https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit) que contém dados importantes sobre as emissões de gás carbônico pelo mundo. O conjunto de dados foi obtido no [Kaggle](www.kaggle.com) e consiste em emissões de CO2 per capita de todos os países do mundo de 1990 a 2019.
#
# Neste desafio, a sua função é efetuar a leitura desse link do Google Planilhas e depois salvar o DataFrame obtido no formato CSV.

# %%
# https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit
import pandas as pd

sheet_id = '1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv'

# %%
data = pd.read_csv(url)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         215 non-null    object
#  1   country_code    215 non-null    object
#  2   Region          216 non-null    object
#  3   Indicator Name  215 non-null    object
#  4   1990            185 non-null    object
#  5   1991            186 non-null    object
#  6   1992            189 non-null    object
#  7   1993            189 non-null    object
#  8   1994            189 non-null    object
#  9   1995            190 non-null    object
#  10  1996            190 non-null    object
#  11  1997            190 non-null    object
#  12  1998            189 non-null    object
#  13  1999            189 non-null    object
#  14  2000            190 non-null    object
#  15  2001            190 non-null    object
#  16  2002            191 non-null    object
# ...

# %%
data.head()
# Out:
#        Country country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# ...

# %%
data.shape
# Out:
# (216, 35)

# %%
data.to_csv('data/co2_from_google_sheet.csv', index=False)
